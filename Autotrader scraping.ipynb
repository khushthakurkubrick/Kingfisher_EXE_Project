# %%
import requests as r
from bs4 import BeautifulSoup
import pandas as pd

years = ['2020','2021']

make_list = []

price_list = []
desc_list = []
image_list = []
year_list = []
type_list = []
mileage_list = []
capacity_list = []
power_list = []
transmission_list = []
fuel_list = []

location_list = []

makes_models = {'AC': ['cobra'],
                'Abarth': ['124%20Spider', '500', '500c', '595', '595c','695', '695c', 'Grande%20Punto', 'Punto%20Evo'],
                'Axiam': ['Crossover', 'Ecity'],
                'Alfa%20Romeo':['145', '146', '147', '156','156%20Sportwagon','159','159%20Sportwagon','164','166','2000', '4c','8c','Brera','Gt', 'Gtv', 'Giulia', 'Giulietta','Junior','Mito', 'Spider','Stelvio'],
                'Alpine':['A110'],
                'Ariel':['Atom','Nomad'],
                'Aston%20Martin':['Cygnet', 'DB%20AR1','Db11','DB2%2F4','Db5','Db6','Db7','Db9','Dbs','Dbx','Lagonda','Le%20Mans','Rapide','Rapide%20S','V12%20Zagato','V8','Vanquish','Vantage','Virage']}
                'Audi':['100','80','A1','A2','A3','A3%20Cabriolet','A4','A4%20Allroad','A4%20Avant','A4%20Cabriolet','A5','A5%20Cabriolet','A6%20Allroad','A6%20Avant','A6%20Saloon','A6%20Unspecified','A7','A8','Allroad','Cabriolet','Coupe','Q2','Q3','Q4%20e-tron','Q5','Q6','Q7','Q8','R8','RS%20Q3','Rs%20E-Tron%20Gt','RS3','RS4','RS4%20Avant','RS4%20Cabriolet','RS5','RS6','RS6%20Avant','RS7','Rsq8','S1','S3','S4','S4%20Avant','S4%20Cabriolet','S5','S6%20Avant','S6%20Saloon','S7','S8','SQ2','SQ5','SQ7','SQ8','TT','TT%20RS','TTS','E-Tron','E-Tron%20Gt','E-Tron%20S','quattro'],
                'Austin':['1300','A30','Ambassador','Healey','Metro','Mini','Princess'],
                'Bac':['Mono'],
                'BMW':['1%20Series','2%20Series','2%20Series%20Active%20Tourer','2%20Series%20Gran%20Coupe','2%20Series%20Gran%20Tourer','2002','3%20Series','3%20Series%20Gran%20Turismo','4%20Series','4%20Series%20Gran%20Coupe','5%20Series','5%20Series%20Gran%20Turismo','6%20Series','6%20Series%20Gran%20Coupe','6%20Series%20Gran%20Turismo','7%20Series','8%20Series','8%20Series%20Gran%20Coupe','Alpina%20B10','Alpina%20B3','Alpina%20B3%20S','Alpina%20B4','Alpina%20B5','Alpina%20B8','Alpina%20D3','Alpina%20D4','Alpina%20D5','Alpina%20D5%20S','Alpina%20Roadster','Alpina%20Unspecified%20Models','Alpina%20Xb7','Alpina%20Xd3','Isetta','M2','M3','M4','M5','M6','M6%20Gran%20Coupe','M8','M8%20Gran%20Coupe','X1','X2','X3','X3%20M','X4','X4%20M','X5','X5%20M','X6','X6%20M','X7','Z1','Z3','Z3%20M','Z4','Z4%20M','Z8','i3','I4','i8','IX','IX3'],
                'Beauford':['Open%20Tourer','Series%203'],
                'Bentley':['Arnage','Azure','Bentayga','Brooklands','Continental','Eight','Flying%20Spur','Mark%20Vi','Mulsanne','Series%20III','T%20Series','Turbo%20R','Turbo%20RT'],
                'Bowler':['Bulldog'],
                'Bristol':['400'],
                'Bugatti':['Chiron', 'Veyron'],
                'Buick':['Park%20Avenue', 'Riviera'],
                'Cupra':['Ateca','Formentor','Leon'],
                'Cadillac':['Allante','BLS','CTS','Escalade','SRX','Seville'],
                'Carbodies':['Black%20Cab'],
                'Caterham':['21','Seven','Super%20Seven%20Convertible','Super%20Seven%20Sports%202dr'],
                'Chesil':['Speedster'],
                'Chevrolet':['Astro','Aveo','C20','Camaro','Captiva','Chevy','Corvette','Cruze','El%20Camino','Epica','Gmc','Kalos','Lacetti','Matiz','Orlando','Ssr','Silverado','Spark','Tacuma','Trax','Volt'],
                'Chrysler':['300C','Crossfire','Delta','Grand%20Voyager','PT%20Cruiser','Pacifica','Sebring','Viper','Voyager','Ypsilon'],
                'Citroen':['2%20CV','AX','Berlingo','C-Crosser','C1','C2','C3','C3%20Aircross','C3%20Picasso','C3%20Pluriel','C4','C4%20Cactus','C4%20Picasso','C4%20Spacetourer','C5','C5%20Aircross','C6','C8','DS3','Ds3%20Cabrio','DS4','DS5','Dispatch','Grand%20C4%20Picasso','Grand%20C4%20Spacetourer','Nemo%20Multispace','Relay','Saxo','SpaceTourer','Xsara','Xsara%20Picasso','ZX'],
                'Corvette':['C5','C6','C7','C8%20Stingray','Stingray','Z06'],
                'Custom%2Vehicle':['Replica'],
                'DS%20AUTOMOBILES':['DS%203','DS%203%20CABRIO','DS%203%20CROSSBACK','DS%204','DS%204%20CROSSBACK','DS%205','DS%207%20CROSSBACK','DS%209'],
                'Dacia':['Duster','Logan%20MCV','Logan%20MCV%20Stepway','Sandero','Sandero%20Stepway'],
                'Daewoo':['Matiz'],
                'Daihatsu':['Atrai','Charade','Copen','Cuore','Materia','Sirion','Sportrak','Terios'],
                'Daimler':['Limousine','Saloon' ,'Sovereign','Super%20Eight','V8-250','XJ%20Series','XJ12'],
                'Dax':['Tojeiro'],
                'Dodge':['Avenger','Caliber','Challenger','Charger','Durango','Journey','Nitro','RAM','Viper'],
                'Ferrari':['208','246','250','308','328','348','355%20F1','360','400','430','456','456M','458','488','488%20Pista','512','550','575M','599','612','812%20Gts','812%20Superfast','California','Daytona','Dino%20246%20Gts','Enzo','F12%20Berlinetta','F12%20Tdf','F355','F430','F8%20Spider','F8%20Tributo','FF','Gtc4lusso','Laferrari','Portofino','Portofino%20M','Roma','Sf90%20Stradale','Scuderia%20Spider','Superamerica','Testarossa'],
                'Fiat':['124%20Spider','126','2300','500','500C','500L','500X','500x%20Dolcevita','500E','500E%20C','600','Abarth','Barchetta','Bravo','Cinquecento','Coupe','Doblo','Ducato','Fiorino','Fullback','Grande%20Punto','Idea','Multipla','Panda','Punto','Punto%20Evo','Qubo','Scudo','Sedici','Seicento','Spider','Stilo','Talento','Tipo','Uno'],
                'Ford':['Anglia','B-Max','Bronco','C-Max','Capri','Consul','Cortina','Cougar','Crown%20Victoria','Custom%20Cab','EcoSport','Edge','Escort','Expedition','Explorer','F100','F150','Fiesta','Flex','Focus','Focus%20C-Max','Focus%20CC','Freda','Fusion','GT','Galaxy','Granada','Grand%20C-Max','Grand%20Tourneo%20Connect','Ka','Ka%2B','Kuga','Maverick','Model%20T','Mondeo','Mustang','Mustang%20Mach-E','P100','Probe','Puma','Ranchero','Ranger','S-Max','Scorpio','Sierra','Streetka','Thunderbird','Tourneo%20Connect','Tourneo%20Courier','Tourneo%20Custom','Transit','Transit%20Connect','Transit%20Courier','Transit%20Custom'],
                'GMC':['Pickup','Sierra','Yukon'],
                'Gardener':['Douglas'],
                'Great Wall':['Steed'],
                'Honda':['Accord','CR-V','CR-X','CR-Z','Civic','Elysion','FR-V','Fit','Freed','HR-V','Honda%20E','Insight','Integra','Jazz','Legend','Logo','NSX','Odyssey','Prelude','S2000','Shuttle','Stepwagon','Stream'],
                'Hummer':['H2','H3'],
                'Hyundai':['Accent','Amica','Atoz','Bayon','Coupe','Elantra','Getz','Grandeur','Ioniq','Ioniq%205','Kona','Matrix','Nexo','S-Coupe','Santa%20Fe','Sonata','Tucson','Terracan','Trajet','Veloster','i10','i20','i30','i40','i800','Iload','ix20','ix35'],
                'Infiniti':['EX','FX','G','M','Q30','Q50','Q60','Q70','QX30','QX50','QX70'],
                'Isuzu':['D-Max','Gemini','Rodeo','Trooper','Vehicross'],
                'Iveco':['Daily'],
                'Jaguar':['C-Type', 'E-PACE','E-Type','F-PACE','F-Type','I-Pace','Mark Ii','S-Type','SS','X-Type','XE','XF','Xfr-S','XJ','XJR','XJS','XK','XK120','XK150','XK8','XKR','XKR-S'],
                'Jeep':['Cherokee','Commander','Compass','Grand%20Cherokee','Patriot','Renegade','Willys' ,'Wrangler'],
                'Jensen':['Interceptor'],
                'Kia':['Carens','Ceed','Cerato','EV6','Magentis','Mentor','Niro','Optima','Picanto','Proceed','Rio','Sedona','Sorento','Soul','Sportage','Stinger','Stonic','Venga','Xceed'],
                'LEVC':['TX'],
                'Lamborghini':['Aventador','Countach','Diablo','Gallardo','Huracan','Murcielago','Urus'],
                'Lancia':['Beta','Fulvia'],
                'Land%20Rover':['110','90','Defender%20110','Defender%20130','Defender%2090','Defender%20Unspecified','Discovery','Discovery%203','Discovery%204','Discovery%20Sport','Freelander','Freelander%202','Lightweight','Modified','Range%20Rover','Range%20Rover%20Evoque','Range%20Rover%20Sport','Range%20Rover%20Velar','Series%20I','Series%20II','Series%20III'],
                'Lexus':['CT%20200h','ES%20300h','GS%20250','GS%20300','GS%20430','GS%20450h','GS%20F','GS%20Unspecified','IS%20200 ','IS%20220d','IS%20250','IS%20300','IS%20F','IS%20Unspecified','LC%20500','LS%20400','LS%20430','LS%20460','LS%20500h','LS%20600h','LS%20Unspecified','LX','NX%20200t','NX%20300h','Nx%20350h','NX%20450h%2B','NX%20Unspecified','RC%20200t','RC%20300h','RC%20F','RX%20200t','RX%20300','RX%20350','RX%20400h','RX%20450h','RX%20L%20450h','RX%20Unspecified','SC%20430','UX%20250h','Ux%20300e'],
                'Lincoln':['Continental','Mkx','Mark%20Viii','Navigator'],
                'Locust':['Seven'],
                'London%20Taxis%20International':['TX4','Txii'],
                'Lotus':['340R','Elan','Elise','Elise%20S','Esprit','Europa','Evora','Excel','Exige','Seven'],
                'MG':['GS','Mg%20Hs','Mg%20Zs','MG3','MG5','MG6','MGA','MGB','MGB%20GT','MGC','MGF','Maestro','Metro','Midget','RV8','TA','TD','TF','ZR','ZT'],
                'MINI':['Clubman','Clubvan','Convertible','Countryman','Coupe','Electric','Hatch','Paceman','Roadster','Unspecified'],
                'Mahindra':['CJ3'],
                'Maserati':['3200','4200','Biturbo','Bora','Coupe','Ghibli','GranCabrio','Gransport','Granturismo','Levante','MC20','Quattroporte','Shamal','Spyder'],
                'Maybach':['57','62'],
                'Mazda':['323','B2500','BT-50','Biante','Bongo','CX-3','CX-30','CX-5','CX-7','Eunos','MX-3','MX-30','MX-5','MX-5%20RF','Mazda2','Mazda3','Mazda5','Mazda6','RX-7','RX-8','Xedos%206'],
                'McLaren':['12C','540C','570GT','570S','600LT','620R','650S','675LT','720S','765LT','GT','P1','Senna'],
                'Mercedes-Benz':['190','190%20SL','200','220','230','230%20SL','240','250','250%20SL','260','280','280%20SL','300','310','320','350','380','450','500','560','560SL','600','A%20Class','AMG','Amg%20Gt','B%20Class','C%20Class','CL','CLA%20Class','CLC%20Class','CLK','CLS','Citan','E%20Class','Eqa','Eqc','Eqs','Eqv','G%20Class','GL%20Class','GLA%20Class','Glb%20Class','GLC%20Class','GLE%20Class','GLS%20Class','M%20Class','Maybach%20Gls%20Class','Maybach%20S%20Class','R%20Class','S%20Class','Se%20Class','Sec%20Series','SL%20Class','SLC','SLK','SLR%20McLaren','SLS','Sprinter','Traveliner','V%20Class','Vaneo','Viano','Vito','X%20Class','Evito'],
                'Mev':['Exocet'],
                'Microcar':['M.Go'],
                'Mitsubishi':['ASX','Carisma','Colt','Colt%20Cabriolet','Delica','Eclipse','Eclipse%20Cross','FTO','Gto','Grandis','Jeep%20J-Series','L200','Lancer','Mirage','Outlander','Pajero','Shogun','Shogun%20Pinin','Shogun%20Sport','Space%20Wagon','i'],
                'Mitsuoka':['Roadster'],
                'Morgan':['3%20Wheeler','4%2F4','Aero','Plus%20Eight','Plus%20Four','Plus%20Six','Roadster'],
                'Morris':['Mini','Minor','Oxford'],
                'Nissan':['200','300','350%20Z','370%20Z','Almera','Almera%20Tino','Bluebird','Cube','Cubic','Elgrand','Figaro','GT-R','Gloria','Juke','Leaf','Maxima%20QX','Micra','Micra%20C%2BC','Murano','NV200','NV300','NV400','Navara','Note','Pathfinder','Patrol','Patrol%20GR','Pickup','Pixo','Prairie','President','Primera','Pulsar','Qashqai','Qashqai%2B2','Serena','Silvia','Skyline','Sunny','Terrano','Terrano%20II','Tiida','Titan','X-Trail','e-NV200','eNV200%20Evalia'],
                'Noble':['M12'],
                'Perodua':['Kelisa','Myvi'],
                'Peugeot':['1007','106','107','108','2008','205','206','206%20CC','206%20SW','207','207%20CC','207%20SW','208','3008','306','307','307%20CC','307%20SW','308','308%20CC','308%20SW','4007','406','407','407%20SW','5008','508','508%20SW','607','807','Bipper%20Tepee','Boxer','Expert','Expert%20Tepee','Partner','Partner%20Tepee','RCZ','Rifter','Traveller','E-Expert','E-Partner','E-Rifter'],
                'Pilgrim':['Sumo'],
                'Polestar':['Polestar%202'],
                'Pontiac':['Grand%20Prix','Trans%20Am'],
                'Porsche':['356','718%20Boxster','718%20Cayman','718%20Spyder','911','918','924','928','944','968','Boxster','Cayenne','Cayman','Macan','Panamera','Taycan'],
                'Proton':['GEN-2','Satria%20Neo','Savvy'],
                'Reo':['Flying%20Cloud'],
                'Radical':['Rapture'],
                'Rage':['Comet'],
                'Raptor':['R'],
                'Reliant':['Regal','Rialto','Robin'],
                'Renault':['5','Arkana','Captur','Clio','Espace','GTA','Grand%20Espace','Grand%20Modus','Grand%20Scenic','Kadjar','Kangoo','Kangoo%20Maxi','Koleos','Laguna','Master','Megane','Modus','Scenic','Scenic%20RX4','Scenic%20Xmod','Trafic','Twingo','Twizy','Wind','Zoe'],
                'Reva':['G-Wiz'],
                'Robin%20Hood':['Project%202B'],
                'Rolls-Royce':['20%2F25','Corniche','Cullinan','Dawn','Ghost','Phantom','Silver20%Cloud','Silver20%Dawn','Silver20%Seraph','Silver20%Shadow','Silver20%Spirit','Silver20%Spur','Wraith'],
                'Rover':['100','200','25','45','75','7520%Tourer','800','City20%Rover','Metro','Mini','P2','P6','Streetwise' ],
                'SEAT':['Alhambra','Altea','Altea20%XL','Arona','Arosa','Ateca','Cupra20%Leon','Cordoba20%Vario','Exeo','Ibiza','Leon','Mii','Tarraco','Toledo' ],
                'SKODA':['Citigo','Enyaq','Fabia','Favorit','Felicia','Kamiq','Karoq','Kodiaq','Octavia','Rapid','Rapid20%Spaceback','Roomster','Scala','Superb','Yeti'],
                'Saab':['9-3','9-5','900','9000'],
                'Singer':['Gazelle'],
                'Smart':['Roadster','forfour','fortwo'],
                'SsangYong':['Korando','Korando%20Sports','Musso','Rexton','Rodius','Tivoli','Tivoli%20XLV','Turismo'],
                'Subaru':['BRZ','Exiga','Forester','Impreza','Justy','Legacy','Levorg','Outback','Tribeca','WRX20%STI','XV'],
                'Sunbeam':['Tiger'],
                'Suzuki':['Across','Alto','Baleno','Cappuccino','Celerio','Grand20%Vitara','Ignis','Jimny','Kizashi','Lapin','Liana','SX4','SX420%S-Cross','Splash','Swace','Swift','Vitara','Wagon20%R'],
                'TVR':['420','Cerbera','Chimaera','Grantura','Griffith','Sagaris','Tamora','Tuscan'],
                'Tesla':['Model20%3','Model20%S','Model20%X','Roadster'],
                'Tiger':['Avon','Cat20%E1'],
                'Toyota':['AYGO','Alphard','Altezza','Aqua','Auris','Avensis','Avensis20%Verso','C-HR','Camry','Carina','Carina20%E','Celica','Century','Corolla','Corolla20%Verso','Cressida','Crown','Emina','Estima','Fj20%Cruiser','GT86','Granvia','HiAce','Highlander','Hilux','Land20%Cruiser','Land20%Cruiser20%Amazon','Land20%Cruiser20%Colorado','MR2','Mirai','Noah','PROACE20%Verso','Paseo','Passo','Picnic','Prado','Previa','Prius','Prius%2B','Proace','RAV4','Ractis','Sienta','Soarer','Starlet','Starlet20%Glanza20%V','Supra','Surf','Townace','Tundra','Urbancruiser','Vellfire','Verso','Verso20%S','Voxy','Will','Wish','Yaris','Yaris20%Cross','Yaris20%Verso','iQ'],
                'Triumph':['GT6','Herald','Spitfire','Stag','TR4','TR5','TR6','TR7'],
                'Ultima':['Gtr'],
                'Vauxhall':['ADAM','Agila','Ampera','Antara','Astra','Astra20%GTC','Calibra','Cascada','Cavalier','Combo','Combo20%Life','Combo20%Tour','Combo-E','Combo-E20%Life','Corsa','Crossland','Crossland20%X','Frontera','Grandland','Grandland20%X','Insignia','Lotus20%Carlton','Meriva','Mokka','Mokka20%X','Monaro','Movano','Nova','Omega','Signum','Tigra','VX220','VXR8','Vectra','Viva','Vivaro','Vivaro20%Life','Vivaro-E','Vivaro-E20%Life','Zafira','Zafira20%Tourer' ],
                'Venturi':['Atlantique'],
                'Volkswagen':['Amarok','Arteon','Beetle','Bora','CC' ,'Caddy','Caddy20%Camper','Caddy20%Life','Caddy20%Maxi','Caddy20%Maxi20%Life','California','Campervan','Caravelle','Corrado' ,'Eos','Fox','Golf','Golf20%Plus','Golf20%SV','Grand20%California','ID.3','ID.4','Jetta','Karmann','Lupo','Passat','Phaeton','Polo','Scirocco','Sharan','T-Cross','T-Roc','Taigo','Tiguan','Tiguan20%Allspace','Touareg','Touran','Transporter','Transporter20%Shuttle','Transporter20%Sportline','up%21'],
                'Volvo':['240','460','740','850','940','960','C30','C70','S40','S60','S70','S80','S90','V40','V4020%Cross20%Country','V50','V60','V6020%Cross20%Country','V70','V7020%Cross20%Country','V90','V9020%Cross20%Country','XC40','XC60','XC70','XC90'],
                'Westfield':['2000','Sei','Sport'],
                'Zenos':['E10']}


for key, value in makes_models.items():
    for model in value:
        for year in years:
            pageno = 0
            for page in range(10):
                pageno += 1


                url = fr'https://www.autotrader.co.uk/car-search?sort=price-asc&postcode=sw1a2aa&radius=1500&make={key}&model={model}&include-delivery-option=on&year-from={year}&year-to={year}&page={pageno}'

                useragent = 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/96.0.4664.110 Safari/537.36'
                response = r.get(url, headers = {'user-agent': useragent})

                soup = BeautifulSoup(response.content, 'html.parser')

                full_results = soup.find_all('div', {'class':'product-card__inner'})
                model_results = list(soup.find_all('h3', {'class': 'product-card-details__title'}))    
                desc_results = list(soup.find_all('p', {'class': 'product-card-details__subtitle'}))    
                price_results = list(soup.find_all('div', {'class': 'product-card-pricing__price'}))
                image_results = list(soup.find_all('img', {'class': 'product-card-image__image product-card-image__main-image'}))

                full_results_fix = full_results[0:10]

                






                full_results_fix = full_results[0:10]
                for i in full_results_fix:
                    year_result = i.find_all('li', {'class':'atc-type-picanto--medium'})[0].text.split()
                    make_results = list(soup.find_all('input', {'class': 'js-field-value'}))
                    make_list.append(make_results[0]['value'])
                        
                    
                        
                    
                    if len(year_result[0]) == 4:
                        try:
                            j = list(i.find_all('span', {'class': 'product-card-seller-info__spec-item-copy'}))
                            if len(j) == 1 and type(int(j)) != int:
                                location_list.append(j[0].text)
                            elif len(j) == 2:
                                location_list.append(j[1].text)
                            else:
                                location_list.append(None)
                        except:
                            location_list.append(None)
                        try:
                            desc_list.append(i.find('p', {'class': 'product-card-details__subtitle'}).text.strip())
                        except:
                            desc_list.append(None)
                        try:
                            price_list.append(i.find('div', {'class': 'product-card-pricing__price'}).text.strip())
                        except:
                            price_list.append(None)
                        try:
                            image_list.append((i.find('img', {'class': 'product-card-image__image product-card-image__main-image'})['src']))
                        except:
                            image_list.append(None)
                        try:
                            year_list.append(year_result[0])
                        except:
                            year_list.append(None)
                        try:
                            type_list.append(i.find_all('li', {'class': 'atc-type-picanto--medium'})[1].text)
                        except:
                            type_list.append(None)
                        try:
                            mileage_list.append(i.find_all('li', {'class': 'atc-type-picanto--medium'})[2].text)
                        except:
                            mileage_list.append(None)
                        try:
                            capacity_list.append(i.find_all('li', {'class': 'atc-type-picanto--medium'})[3].text)
                        except:
                            capacity_list.append(None)
                        try:
                            power_list.append(i.find_all('li', {'class': 'atc-type-picanto--medium'})[4].text)
                        except:
                            power_list.append(None)
                        try:
                            transmission_list.append(i.find_all('li', {'class': 'atc-type-picanto--medium'})[5].text)
                        except:
                            transmission_list.append(None)
                        try:
                            fuel_list.append(i.find_all('li', {'class': 'atc-type-picanto--medium'})[6].text)
                        except:
                            fuel_list.append(None)
                        
                    
                    
                


dict_of_lists = {'Manufacturer': make_list, 'Description': desc_list, 'Price': price_list, 'Year': year_list, 'Type': type_list, 'Image': image_list, 'Mileage': mileage_list, 'Capacity': capacity_list, 'Power': power_list, 'Transmission': transmission_list, 'Fuel': fuel_list, 'Location': location_list }

df = pd.DataFrame(dict_of_lists)
df = df.drop_duplicates(subset = None)
df
# Out:
#   File "<ipython-input-2-af23081eb7a8>", line 29
#     'Audi':['100','80','A1','A2','A3','A3%20Cabriolet','A4','A4%20Allroad','A4%20Avant','A4%20Cabriolet','A5','A5%20Cabriolet','A6%20Allroad','A6%20Avant','A6%20Saloon','A6%20Unspecified','A7','A8','Allroad','Cabriolet','Coupe','Q2','Q3','Q4%20e-tron','Q5','Q6','Q7','Q8','R8','RS%20Q3','Rs%20E-Tron%20Gt','RS3','RS4','RS4%20Avant','RS4%20Cabriolet','RS5','RS6','RS6%20Avant','RS7','Rsq8','S1','S3','S4','S4%20Avant','S4%20Cabriolet','S5','S6%20Avant','S6%20Saloon','S7','S8','SQ2','SQ5','SQ7','SQ8','TT','TT%20RS','TTS','E-Tron','E-Tron%20Gt','E-Tron%20S','quattro'],
#     ^
# IndentationError: unexpected indent

# %%
import requests as r
from bs4 import BeautifulSoup
import pandas as pd


url = fr'https://www.autotrader.co.uk/car-search?sort=price-asc&postcode=sw1a2aa&radius=1500&make=Audi&model=A1&include-delivery-option=on&year-from=2021&year-to=2021&page=1'

useragent = 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/96.0.4664.110 Safari/537.36'
response = r.get(url, headers = {'user-agent': useragent})

soup = BeautifulSoup(response.content, 'html.parser')

full_results = soup.find_all('div', {'class':'product-card__inner'})
full_results_fix = full_results[0:10]

desc_list = []
price_list = []
image_list = []

for i in full_results_fix:

    try:
        desc_list.append(i.find('p', {'class': 'product-card-details__subtitle'}).text.strip())
    except:
        desc_list.append(None)
    try:
        price_list.append(i.find('div', {'class': 'product-card-pricing__price'}).text.strip())
    except:
        price_list.append(None)
    try:
        image_list.append((i.find('img', {'class': 'product-card-image__image product-card-image__main-image'})['src']))
    except:
        image_list.append(None)
              
            
print(len(desc_list))
print(len(price_list))
print(len(image_list))
# Out:
# 10
# 10
# 10

# %%
df
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-14-00cf07b74dcd> in <module>
# ----> 1 df
#
# NameError: name 'df' is not defined

# %%
print(len(desc_list), len(price_list), len(year_list), len(type_list), len(image_list), len(mileage_list), len(capacity_list), len(power_list), len(transmission_list), len(fuel_list))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-9f9422f53683> in <module>
# ----> 1 print(len(desc_list), len(price_list), len(year_list), len(type_list), len(image_list), len(mileage_list), len(capacity_list), len(power_list), len(transmission_list), len(fuel_list))
#
# NameError: name 'desc_list' is not defined

# %%
print(len(desc_list))
print(len(price_list))
print(len(image_list))
# Out:
# 27206
# 27206
# 27206

# %%
import requests as r
from bs4 import BeautifulSoup
import pandas as pd

url = fr'https://www.autotrader.co.uk/car-search?sort=price-asc&postcode=sw1a2aa&radius=1500&make=Audi&model=A1&include-delivery-option=on&year-from=2010&year-to=2010&page=1'

useragent = 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/96.0.4664.110 Safari/537.36'
response = r.get(url, headers = {'user-agent': useragent})

soup = BeautifulSoup(response.content, 'html.parser')

full_results = soup.find_all('div', {'class':'product-card__inner'})

image_list  = []
image_results = list(soup.find_all('img', {'class': 'product-card-image__image product-card-image__main-image'}))
for i in image_results:
    image_list.append(i['src'])
    
image_list
# Out:
# ['https://m.atcdn.co.uk/a/media/w340h255pf7f7f5/ac8b50ce26014bd3811e12ac9da04d01.jpg',
#  'https://m.atcdn.co.uk/a/media/w340h255pf7f7f5/636d100e4cc54e20a27f6dfa3977d74b.jpg',
#  'https://m.atcdn.co.uk/a/media/w340h255pf7f7f5/34b689667aa84cf9a32aa6ecad3ec867.jpg',
#  'https://m.atcdn.co.uk/a/media/w340h255pf7f7f5/50b8d88dc8cf48efa8ceb3597396a13b.jpg',
#  'https://m.atcdn.co.uk/a/media/w340h255pf7f7f5/ae67113467614dcfa32380661ee7d3c4.jpg',
#  'https://m.atcdn.co.uk/a/media/w340h255pf7f7f5/4a0d6ac7d39846e087d34e1b3dfdf978.jpg',
#  'https://m.atcdn.co.uk/a/media/w340h255pf7f7f5/3ee6d53615c543d8bb4fc7c1c286fe9c.jpg',
#  'https://m.atcdn.co.uk/a/media/w340h255pf7f7f5/fd5530183c15496eb762c399c2adb89c.jpg',
#  'https://m.atcdn.co.uk/a/media/w340h255pf7f7f5/a38eb2e4c957461e96cdac4b77ae8bd6.jpg',
#  'https://m.atcdn.co.uk/a/media/w340h255pf7f7f5/75c6f491d2994f239bfa24bc41681cec.jpg',
#  'https://m.atcdn.co.uk/a/media/w340h255pf7f7f5/e4241eccd9514a2e90cfabdb73622d62.jpg']

# %%
len(image_list)
# Out:
# 11
